# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
def restructure_event_data():
    event_df = pd.read_csv('data/custom/retrosheet_events.csv')
    event_df.drop(columns=[
        'date', 'game_num', 'misc', 'acquisition_info', 'visiting_team_game_num', 'home_team_game_num',
        'completion_info', 'forfeit_info', 'protest_info', 'visiting_line_score',
        'home_line_score', 'visiting_starting_pitcher_name', 'home_starting_pitcher_name',
        'visiting_1_name', 'visiting_2_name', 'visiting_3_name', 'visiting_4_name',
        'visiting_5_name', 'visiting_6_name', 'visiting_7_name', 'visiting_8_name',
        'visiting_9_name', 'home_1_name', 'home_2_name', 'home_3_name', 'home_4_name',
        'home_5_name', 'home_6_name', 'home_7_name', 'home_8_name',
        'home_9_name', 'ump_home_name', 'ump_first_name', 'ump_second_name',
        'ump_third_name', 'ump_lf_name', 'ump_rf_name', 'visiting_manager_name',
        'home_manager_name', 'winning_pitcher_id', 'winning_pitcher_name', 'losing_pitcher_id',
        'losing_pitcher_name', 'save_pitcher_id', 'save_pitcher_name', 'game_winning_rbi_id',
        'game_winning_rbi_name', 
    ], axis=1, inplace=True)
    event_df.rename(columns={
        'visiting_team': 'team_v',
        'visiting_team_league': 'league_v',
        'home_team': 'team_h',
        'home_team_league': 'league_h',
        'visiting_score': 'runs_v',
        'home_score': 'runs_h',
        'time_of_game_minutes': 'duration',
        # visiting team stats
        'visiting_abs': 'abs_v',
        'visiting_hits': 'hits_v',
        'visiting_doubles': 'x2B_v',
        'visiting_triples': 'x3B_v',
        'visiting_homeruns': 'HR_v',
        'visiting_rbi': 'RBI_v',
        'visiting_sac_hits': 'sac_hits_v',
        'visiting_sac_flies': 'sac_flies_v',
        'visiting_hbp': 'HBP_v',
        'visiting_bb': 'BB_v',
        'visiting_iw': 'IBB_v',
        'visiting_k': 'K_v',
        'visiting_sb': 'SB_v',
        'visiting_cs': 'CS_v',
        'visiting_gdp': 'GDP_v',
        'visiting_ci': 'CI_v',
        'visiting_lob': 'LOB_v',
        'visiting_pitchers_used': 'num_pitchers_v',
        'visiting_individual_er': 'IER_v',
        'visiting_er': 'ER_v',
        'visiting_wp': 'WP_v',
        'visiting_balks': 'balks_v',
        'visiting_po': 'PO_v',
        'visiting_assists': 'assists_v',
        'visiting_errors': 'E_v',
        'visiting_pb': 'PB_v',
        'visiting_dp': 'x2P_v',
        'visiting_tp': 'x3P_v',
        'visiting_starting_pitcher_id': 'SP_v',
        'visiting_1_id': 'batter1_v',
        'visiting_2_id': 'batter2_v',
        'visiting_3_id': 'batter3_v',
        'visiting_4_id': 'batter4_v',
        'visiting_5_id': 'batter5_v',
        'visiting_6_id': 'batter6_v',
        'visiting_7_id': 'batter7_v',
        'visiting_8_id': 'batter8_v',
        'visiting_9_id': 'batter9_v',
        'visiting_1_pos': 'pos1_v',
        'visiting_2_pos': 'pos2_v',
        'visiting_3_pos': 'pos3_v',
        'visiting_4_pos': 'pos4_v',
        'visiting_5_pos': 'pos5_v',
        'visiting_6_pos': 'pos6_v',
        'visiting_7_pos': 'pos7_v',
        'visiting_8_pos': 'pos8_v',
        'visiting_9_pos': 'pos9_v',
        'visiting_manager_id': 'manager_v',
        # home team stats
        'home_abs': 'abs_h',
        'home_hits': 'hits_h',
        'home_doubles': 'x2B_h',
        'home_triples': 'x3B_h',
        'home_homeruns': 'HR_h',
        'home_rbi': 'RBI_h',
        'home_sac_hits': 'sac_hits_h',
        'home_sac_flies': 'sac_flies_h',
        'home_hbp': 'HBP_h',
        'home_bb': 'BB_h',
        'home_iw': 'IBB_h',
        'home_k': 'K_h',
        'home_sb': 'SB_h',
        'home_cs': 'CS_h',
        'home_gdp': 'GDP_h',
        'home_ci': 'CI_h',
        'home_lob': 'LOB_h',
        'home_pitchers_used': 'num_pitchers_h',
        'home_individual_er': 'IER_h',
        'home_er': 'ER_h',
        'home_wp': 'WP_h',
        'home_balks': 'balks_h',
        'home_po': 'PO_h',
        'home_assists': 'assists_h',
        'home_errors': 'E_h',
        'home_pb': 'PB_h',
        'home_dp': 'x2P_h',
        'home_tp': 'x3P_h',
        'home_starting_pitcher_id': 'SP_h',
        'home_1_id': 'batter1_h',
        'home_2_id': 'batter2_h',
        'home_3_id': 'batter3_h',
        'home_4_id': 'batter4_h',
        'home_5_id': 'batter5_h',
        'home_6_id': 'batter6_h',
        'home_7_id': 'batter7_h',
        'home_8_id': 'batter8_h',
        'home_9_id': 'batter9_h',
        'home_1_pos': 'pos1_h',
        'home_2_pos': 'pos2_h',
        'home_3_pos': 'pos3_h',
        'home_4_pos': 'pos4_h',
        'home_5_pos': 'pos5_h',
        'home_6_pos': 'pos6_h',
        'home_7_pos': 'pos7_h',
        'home_8_pos': 'pos8_h',
        'home_9_pos': 'pos9_h',
        'home_manager_id': 'manager_h',
    }, inplace=True)
    event_df.rename(columns={'Season': 'season'}, inplace=True)
    return event_df
    
event_df = restructure_event_data()
display(event_df)
# Out:
# /var/folders/y0/_yc3t8mn3kx8j1td1w609rl00000gn/T/ipykernel_69350/561374948.py:2: DtypeWarning: Columns (15,16,17,87,89) have mixed types. Specify dtype option on import or set low_memory=False.
#   event_df = pd.read_csv('data/custom/retrosheet_events.csv')
#        Unnamed: 0.1  Unnamed: 0 day_of_week team_v league_v team_h league_h  \
# 0                 0           0         Wed    TOR       AL    SEA       AL
# 1                 1           1         Wed    ATL       NL    CIN       NL
# 2                 2           2         Thu    BAL       AL    CHA       AL
# 3                 3           3         Thu    DET       AL    KCA       AL
# 4                 4           4         Thu    BOS       AL    MIL       AL
# ...             ...         ...         ...    ...      ...    ...      ...
# 98699         98699        2425         Sun    SDN       NL    CHA       AL
# 98700         98700        2426         Sun    CLE       AL    DET       AL
# 98701         98701        2427         Sun    NYA       AL    KCA       AL
# 98702         98702        2428         Sun    TEX       AL    SEA       AL
# 98703         98703        2429         Sun    TBA       AL    TOR       AL
#
#        runs_v  runs_h  num_outs day_night park_id  attendance  duration  \
# 0           6       8        51         N   SEA02     22588.0       154
# 1           0       9        51         D   CIN08     51774.0       127
# 2           5       3        54         D   CHI10     35539.0       142
# 3           5       1        54         N   KAN06     34901.0       148
# 4           5       9        53         D   MIL05     53313.0       172
# ...       ...     ...       ...       ...     ...         ...       ...
# 98699       2       1        66         D   CHI12     20588.0       187
# 98700       2       5        51         D   DET05     41425.0       148
# 98701       2       5        51         D   KAN06     20662.0       144
# 98702       0       1        51         D   SEA03     43997.0       121
# 98703      12       8        54         D   TOR02     42058.0       167
#
#        abs_v  hits_v  x2B_v  x3B_v  HR_v  RBI_v  sac_hits_v  sac_flies_v  \
# 0         36       9      1      1     2      5           0            0
# 1         30       3      0      0     0      0           0            0
# 2         31       8      2      2     0      4           1            1
# 3         33       9      1      2     2      5           0            0
# 4         35      10      0      0     2      5           0            0
# ...      ...     ...    ...    ...   ...    ...         ...          ...
# 98699     36       7      1      0     0      2           0            1
# 98700     33       5      1      0     1      2           0            0
# 98701     32       7      3      0     0      2           0            0
# 98702     30       4      1      0     0      0           0            0
# 98703     43      16      4      0     3     11           0            0
#
#        HBP_v  BB_v  IBB_v  K_v  SB_v  CS_v  GDP_v  CI_v  LOB_v  \
# 0          0     5      0    4     2     0      1     0      8
# 1          0     0      0    5     0     0      0     0      3
# 2          1     1      0    6     0     1      2     0      3
# 3          0     3      0    4     1     1      2     0      4
# 4          0     1      0    3     0     0      2     0      4
# ...      ...   ...    ...  ...   ...   ...    ...   ...    ...
# 98699      0     7      0    8     2     1      2     0     11
# 98700      0     1      0    8     1     0      0     0      5
# 98701      0     3      0    7     0     0      2     0      6
# 98702      0     0      0   11     0     0      1     0      3
# 98703      1     3      0    9     2     0      0     0      8
#
#        num_pitchers_v  IER_v  ER_v  WP_v  balks_v  PO_v  assists_v  E_v  PB_v  \
# 0                   5      6     6     0        0    24         14    1     0
# 1                   5      6     6     1        0    24         10    2     1
# 2                   2      1     1     0        0    27         12    2     0
# 3                   1      0     0     0        0    27         11    1     0
# 4                   3      9     9     0        0    26          7    0     0
# ...               ...    ...   ...   ...      ...   ...        ...  ...   ...
# 98699               6      0     0     0        0    33         13    1     0
# 98700               4      5     5     0        0    24          7    1     0
# 98701               3      5     5     0        0    24         12    1     0
# 98702               3      1     1     0        0    24          4    0     0
# 98703               4      6     6     1        0    27          7    2     0
#
#        x2P_v  x3P_v  abs_h  hits_h  x2B_h  x3B_h  HR_h  RBI_h  sac_hits_h  \
# 0          1      0     34      12      2      1     1      8           2
# 1          1      0     33       9      3      1     1      9           1
# 2          0      0     34       7      1      0     0      1           0
# 3          0      0     31       3      2      0     0      1           0
# 4          0      0     34       9      2      0     5      9           1
# ...      ...    ...    ...     ...    ...    ...   ...    ...         ...
# 98699      1      0     40       7      0      0     0      1           0
# 98700      1      0     32       9      4      0     1      5           0
# 98701      0      0     32      11      0      1     3      5           1
# 98702      0      0     28       4      0      0     0      1           0
# 98703      0      0     40      12      2      2     1      6           0
#
#        sac_flies_h  HBP_h  BB_h  IBB_h  K_h  SB_h  CS_h  GDP_h  CI_h  LOB_h  \
# 0                0      0     2      1    4     0     0      1     0      6
# 1                1      0     5      1    6     0     0      1     0      7
# 2                0      0     5      0    6     1     0      0     0      9
# 3                0      0     3      0    5     1     0      0     0      6
# 4                0      0     7      2    7     0     0      0     0      7
# ...            ...    ...   ...    ...  ...   ...   ...    ...   ...    ...
# 98699            0      1     3      1   16     1     0      1     0     12
# 98700            0      0     6      0    7     1     0      1     0      9
# 98701            1      0     1      0    8     2     1      0     0      6
# 98702            0      1     1      0   10     0     0      0     0      5
# 98703            0      2     3      0    7     0     0      0     0     10
#
#        num_pitchers_h  IER_h  ER_h  WP_h  balks_h  PO_h  assists_h  E_h  PB_h  \
# 0                   3      6     6     0        0    27         16    2     1
# 1                   1      0     0     0        0    27         11    0     0
# 2                   2      4     4     0        1    27         20    1     0
# 3                   2      4     4     0        1    27         15    1     1
# 4                   2      5     5     1        0    27         13    0     0
# ...               ...    ...   ...   ...      ...   ...        ...  ...   ...
# 98699               6      0     0     0        0    33         15    0     1
# 98700               3      1     1     1        0    27          7    1     0
# 98701               4      2     2     0        0    27         14    0     0
# 98702               4      0     0     0        0    27          9    0     0
# 98703               6     12    12     2        0    27          8    0     0
#
#        x2P_h  x3P_h ump_home_id ump_first_id ump_second_id ump_third_id  \
# 0          1      0    barnl901     evanj901      mckej901     hendt901
# 1          0      0    wendh901     pullf901      monte901     harrl901
# 2          2      0    kunkb101     malog901      coont901     kaisk901
# 3          3      0    phild901     dimul901      clara901     pales901
# 4          2      0    neudj901     deegb901      garcr901     reilm901
# ...      ...    ...         ...          ...           ...          ...
# 98699      2      0    macka901     ballb901      hudsm901     tumpj901
# 98700      0      0    bacoj901     hoyej901      libkj901     herna901
# 98701      2      0    vondc901     torrc901      kulpr901     riggj901
# 98702      1      0    millb903     blakr901      carlm901     gibsh902
# 98703      0      0    dejer901     blasc901      eddid901     marqa901
#
#       ump_lf_id ump_rf_id manager_v manager_h      SP_v      SP_h batter1_v  \
# 0           NaN       NaN  mattb101  johnd106  lemad101  parrm101  grifa001
# 1           NaN       NaN  cox-b103  mcnaj801  niekp001  pastf001  mille001
# 2           NaN       NaN  weave801  larut101  palmj001  trous001  bumba001
# 3           NaN       NaN  andes101  freyj801  morrj001  leond001  whitl001
# 4           NaN       NaN  zimmd101  rodgb102  ecked001  slatj001  remyj001
# ...         ...       ...       ...       ...       ...       ...       ...
# 98699       NaN       NaN  melvb001  grifp801  avilp001  urenj001  bogax001
# 98700       NaN       NaN  frant001  hinca001  gioll001  rodre004  kwans001
# 98701       NaN       NaN  boona001  quatm801  kingm002  greiz001  lemad001
# 98702       NaN       NaN  bochb002  servs002  dunnd001  kirbg001  semim001
# 98703       NaN       NaN  cashk001  schnj801  lopej007  parsw001  camij001
#
#        pos1_v batter2_v  pos2_v visiting_2_id.1  pos3_v batter4_v  pos4_v  \
# 0           6  bailb001       9        maybj101       3  veleo101      10
# 1           8  roysj001       4        mattg001       9  hornb001       5
# 2           8  belam101       6        singk001       9  murre001       3
# 3           4  gibsk001       8        kemps001       7  hebnr001       5
# 4           4  burlr001       6        lynnf001       8  ricej001       7
# ...       ...       ...     ...             ...     ...       ...     ...
# 98699       6  kim-h002       4        sotoj001      10  tatif002       9
# 98700       7  ramij003      10        naylj001       3  laurr001       8
# 98701       3  volpa001       6        wella002       2  higak001      10
# 98702       4  seagc001       6        garvm001      10  garca005       9
# 98703       6  lowej002       9        ramih004      10  parei001       5
#
#       batter5_v  pos5_v batter6_v  pos6_v batter7_v  pos7_v batter8_v  pos8_v  \
# 0      hower001       5  bonnb001       7  boser101       8  garcd001       4
# 1      chamc001       3  murpd001       7  pocob001       2  gomel101       6
# 2      decid001       5  may-l101      10  roeng001       7  dauer001       4
# 3      thomj001       3  summc001      10  parrl001       2  peter001       9
# 4      yastc101      10  peret001       3  hobsb101       5  evand002       9
# ...         ...     ...       ...     ...       ...     ...       ...     ...
# 98699  profj001       7  coopg002       3  grist001       8  rosae002       5
# 98700  gonzo001       9  roccb001       6  naylb001       2  freet001       5
# 98701  kinei001       5  cabro002       9  perao002       4  peree005       7
# 98702  lowen001       3  jungj001       5  heimj001       2  tavel001       8
# 98703  aranj001       3  meadc001       4  margm001       8  tapir001       7
#
#       batter9_v  pos9_v batter1_h  pos1_h batter2_h  pos2_h batter3_h  pos3_h  \
# 0      white002       2  cruzj002       4  crair001       8  meyed001       7
# 1      niekp001       1  colld001       8  grifk001       9  concd001       6
# 2      dempr001       2  molib101      10  banna001       5  washc001       7
# 3      wagnm001       6  wilsw001       8  mcrah001      10  bretg001       5
# 4      raded101       2  molip001       4  coopc001       3  david101      10
# ...         ...     ...       ...     ...       ...     ...       ...     ...
# 98699  sullb001       2  andre001       6  remiz001       4  vauga001       3
# 98700  tenaj001       4  meadp001       8  torks001       3  cabrm001      10
# 98701  flore001       8  garcm003       5  wittb002       6  peres002       2
# 98702  carte001       7  crawj002       6  rodrj007       8  ralec001       2
# 98703  pintr003       2  merrw001       9  beltb001      10  bichb001       6
#
#       batter4_h  pos4_h batter5_h  pos5_h batter6_h  pos6_h batter7_h  pos7_h  \
# 0      bochb001       3  hortw101      10  simpj101       9  cox-t101       5
# 1      fostg001       7  dried001       3  bencj101       2  knigr001       5
# 2      johnl101       3  lemoc001       8  bainh001       9  morrj002       4
# 3      aikew001       3  lacop101       7  quirj001       2  hurdc001       9
# 4      oglib001       7  thomg001       8  lezcs001       9  moned101       5
# ...         ...     ...       ...     ...       ...     ...       ...     ...
# 98699  sheeg001       9  grany001      10  sosal001       5  naqut001       7
# 98700  carpk001       9  vierm001       5  ibana001       4  badda001       7
# 98701  melem001       9  olive001       7  massm001       4  bland001       8
# 98702  suare001       5  kelej001       9  frant002       3  canzd001       7
# 98703  schnd001       4  biggc002       3  espis001       5  varsd001       8
#
#       batter8_h  pos8_h batter9_h  pos9_h  season  run_diff  home_victory  \
# 0      stinb101       2  mendm101       6    1980         2             1
# 1      kennj101       4  pastf001       1    1980         9             1
# 2      folem001       2  pryog001       6    1980        -2             0
# 3      whitf001       4  washu001       6    1980        -4             0
# 4      younr001       6  moorc001       2    1980         4             1
# ...         ...     ...       ...     ...     ...       ...           ...
# 98699  thomt002       8  perec005       2    2023        -1             0
# 98700  baezj001       6  rogej004       2    2023         3             1
# 98701  pratn001       3  duffm002      10    2023         3             1
# 98702  fordm002      10  rojaj001       4    2023         1             1
# 98703  heint001       2  edenc001       7    2023        -4             0
#
#        run_total  date_dblhead
# 0             14     198004090
# 1              9     198004090
# 2              8     198004100
# 3              6     198004100
# 4             14     198004100
# ...          ...           ...
# 98699          3     202310010
# 98700          7     202310010
# 98701          7     202310010
# 98702          1     202310010
# 98703         20     202310010
#
# [98704 rows x 121 columns]
