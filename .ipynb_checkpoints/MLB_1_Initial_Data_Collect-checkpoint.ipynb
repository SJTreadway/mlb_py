# %%
# Install Packages

#!pip3 install pybaseball==2.2.7 -- version not updated with season_game_logs fix

# USE BELOW UNTIL NEW VERSION HAS BEEN RELEASED
#!pip3 install pybaseball@git+https://github.com/jldbc/pybaseball.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pybaseball@ git+https://github.com/jldbc/pybaseball.git
#   Cloning https://github.com/jldbc/pybaseball.git to /tmp/pip-install-nvpedpnc/pybaseball_5137d48103434a87b95a0347a1e7f99f
#   Running command git clone --filter=blob:none --quiet https://github.com/jldbc/pybaseball.git /tmp/pip-install-nvpedpnc/pybaseball_5137d48103434a87b95a0347a1e7f99f
#   Resolved https://github.com/jldbc/pybaseball.git to commit aa093f9d52054b8b7ec5988deb2a8dbb7fcb0f89
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: attrs>=20.3.0 in /home/vo/.local/lib/python3.10/site-packages (from pybaseball@ git+https://github.com/jldbc/pybaseball.git) (24.3.0)
# Requirement already satisfied: pyarrow>=1.0.1 in /home/vo/.local/lib/python3.10/site-packages (from pybaseball@ git+https://github.com/jldbc/pybaseball.git) (18.1.0)
# Requirement already satisfied: requests>=2.18.1 in /home/vo/.local/lib/python3.10/site-packages (from pybaseball@ git+https://github.com/jldbc/pybaseball.git) (2.32.3)
# Requirement already satisfied: numpy>=1.13.0 in /home/vo/.local/lib/python3.10/site-packages (from pybaseball@ git+https://github.com/jldbc/pybaseball.git) (2.2.1)
# Requirement already satisfied: lxml>=4.2.1 in /home/vo/.local/lib/python3.10/site-packages (from pybaseball@ git+https://github.com/jldbc/pybaseball.git) (5.3.0)
# Requirement already satisfied: scipy>=1.4.0 in /home/vo/.local/lib/python3.10/site-packages (from pybaseball@ git+https://github.com/jldbc/pybaseball.git) (1.15.0)
# Requirement already satisfied: pygithub>=1.51 in /home/vo/.local/lib/python3.10/site-packages (from pybaseball@ git+https://github.com/jldbc/pybaseball.git) (2.5.0)
# Requirement already satisfied: pandas>=1.0.3 in /home/vo/.local/lib/python3.10/site-packages (from pybaseball@ git+https://github.com/jldbc/pybaseball.git) (2.2.3)
# Requirement already satisfied: beautifulsoup4>=4.4.0 in /home/vo/.local/lib/python3.10/site-packages (from pybaseball@ git+https://github.com/jldbc/pybaseball.git) (4.12.3)
# Requirement already satisfied: tqdm>=4.50.0 in /home/vo/.local/lib/python3.10/site-packages (from pybaseball@ git+https://github.com/jldbc/pybaseball.git) (4.67.1)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/vo/.local/lib/python3.10/site-packages (from pybaseball@ git+https://github.com/jldbc/pybaseball.git) (3.10.0)
# Requirement already satisfied: soupsieve>1.2 in /home/vo/.local/lib/python3.10/site-packages (from beautifulsoup4>=4.4.0->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (2.6)
# Requirement already satisfied: packaging>=20.0 in /home/vo/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (24.2)
# Requirement already satisfied: pillow>=8 in /home/vo/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=2.0.0->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vo/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (4.55.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vo/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/vo/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vo/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in /home/vo/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (0.12.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/vo/.local/lib/python3.10/site-packages (from pandas>=1.0.3->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in /home/vo/.local/lib/python3.10/site-packages (from pandas>=1.0.3->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (2024.2)
# Requirement already satisfied: pynacl>=1.4.0 in /home/vo/.local/lib/python3.10/site-packages (from pygithub>=1.51->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (1.5.0)
# Requirement already satisfied: urllib3>=1.26.0 in /home/vo/.local/lib/python3.10/site-packages (from pygithub>=1.51->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (2.2.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/vo/.local/lib/python3.10/site-packages (from pygithub>=1.51->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (4.12.2)
# Requirement already satisfied: pyjwt[crypto]>=2.4.0 in /home/vo/.local/lib/python3.10/site-packages (from pygithub>=1.51->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (2.10.1)
# Requirement already satisfied: Deprecated in /home/vo/.local/lib/python3.10/site-packages (from pygithub>=1.51->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (1.2.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/vo/.local/lib/python3.10/site-packages (from requests>=2.18.1->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vo/.local/lib/python3.10/site-packages (from requests>=2.18.1->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vo/.local/lib/python3.10/site-packages (from requests>=2.18.1->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (2024.8.30)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/lib/python3/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (3.4.8)
# Requirement already satisfied: cffi>=1.4.1 in /home/vo/.local/lib/python3.10/site-packages (from pynacl>=1.4.0->pygithub>=1.51->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (1.17.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/vo/.local/lib/python3.10/site-packages (from Deprecated->pygithub>=1.51->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (1.17.0)
# Requirement already satisfied: pycparser in /home/vo/.local/lib/python3.10/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub>=1.51->pybaseball@ git+https://github.com/jldbc/pybaseball.git) (2.22)

# %%
import os
from pybaseball import team_game_logs, season_game_logs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
years = list(range(1980, 2025))

teams = [
    "FLA", "LAA", "CAL", "MON", 
    "MIL", "HOU", "ANA", "BAL",
    "BOS", "CHW", "CLE", "DET", 
    "KCR", "MIN", "NYY", "OAK", 
    "SEA", "TBR", "TEX", "TOR", 
    "ARI", "ATL", "CHC", "CIN", 
    "COL", "LAD", "SDP", "MIA", 
    "NYM", "PHI", "PIT", "SFG", 
    "STL", "TBD", "WSN"
]

# %%
def get_game_data_by_team(team, stat_type):
    game_df = pd.DataFrame()
    for year in years:
        temp_df = pd.DataFrame()
        try:
            temp_df = team_game_logs(year, team, stat_type)
            temp_df['Team'] = team
            temp_df['Season'] = year
            game_df = pd.concat((game_df, temp_df))
            print(f'Game {stat_type} data loaded for {team} in {year}')
        except RuntimeError as error:
            print(f'Unable to load game {stat_type} data for {team} in {year}')
    return game_df

# %%
stat_type = 'pitching' #'batting'

for team in teams:
    game_df = get_game_data_by_team(team, stat_type)
    game_df.to_csv(f'data/raw/{team}_{stat_type}.csv')
    print(f'**Game {stat_type} data written to csv for {team}**')

# %%
# Download Event files from Retrosheet
from github import Github
GH_TOKEN = "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"
os.environ["GH_TOKEN"] = GH_TOKEN

event_df = pd.DataFrame()

for year in years:
    try:
        temp_df = season_game_logs(year)
        temp_df['Season'] = year
        event_df = pd.concat((event_df, temp_df))
        print(f'Event data loaded for {year}')
    except ValueError as error:
        print(error)

event_df.to_csv('data/raw/retrosheet_events.csv')
# Out:
# Event data loaded for 1980
# Event data loaded for 1981
# Event data loaded for 1982
# Event data loaded for 1983
# Event data loaded for 1984
# Event data loaded for 1985
# Event data loaded for 1986
# Event data loaded for 1987
# Event data loaded for 1988
# Event data loaded for 1989
# Event data loaded for 1990
# Event data loaded for 1991
# Event data loaded for 1992
# Event data loaded for 1993
# Event data loaded for 1994
# Event data loaded for 1995
# Event data loaded for 1996
# Event data loaded for 1997
# Event data loaded for 1998
# Event data loaded for 1999
# Event data loaded for 2000
# Event data loaded for 2001
# Event data loaded for 2002
# Event data loaded for 2003
# Event data loaded for 2004
# Event data loaded for 2005
# Event data loaded for 2006
# Event data loaded for 2007
# Event data loaded for 2008
# Event data loaded for 2009
# Event data loaded for 2010
# Event data loaded for 2011
# Event data loaded for 2012
# Event data loaded for 2013
# Event data loaded for 2014
# Event data loaded for 2015
# Event data loaded for 2016
# Event data loaded for 2017
# Event data loaded for 2018
# Event data loaded for 2019
# Event data loaded for 2020
# Event data loaded for 2021
# Event data loaded for 2022
# Event data loaded for 2023
# Season game logs not available for 2024

# %%
# combine team data if team has moved locations
team_map = {
    'ANA': 'LAA',
    'CAL': 'LAA',
    'FLA': 'MIA',
    'MON': 'WSN',
    'TBD': 'TBR',
}

raw_loc = 'data/raw'
combined_loc = 'data/custom'

#### Come back to this later after cleaning up Events data ####

def merge_prev_team_data(prev_team):
    target_team = team_map[prev_team]
    combined_df = pd.DataFrame()

    for file in os.listdir(raw_loc):
        f = os.path.join(raw_loc, file)
        if os.path.isfile(f):
            if prev_team in f:
                print(f)
                temp_df = pd.read_csv(f)
                target_df = pd.read_csv(f'{raw_loc}/{target_team}')
                temp_df['Team'] = target_team
                
                print(temp_df.columns)

def combine_batting_pitching_data(team):
    bat_f = os.path.join(raw_loc, f'{team}_batting.csv')
    pitch_f = os.path.join(raw_loc, f'{team}_pitching.csv')

    bat_df = pd.read_csv(bat_f)
    pitch_df = pd.read_csv(pitch_f)

    combined_df = pd.concat([bat_df, pitch_df], axis=1).T.drop_duplicates().T.reset_index(drop=True)
    return combined_df

for team in teams:
    combined_df = combine_batting_pitching_data(team)
    combined_df.to_csv(f'{combined_loc}/{team}.csv')
    print(f'Combined batting and pitching data for {team}')
# Out:
# Combined batting and pitching data for FLA
# Combined batting and pitching data for LAA
# Combined batting and pitching data for CAL
# Combined batting and pitching data for MON
# Combined batting and pitching data for MIL
# Combined batting and pitching data for HOU
# Combined batting and pitching data for ANA
# Combined batting and pitching data for BAL
# Combined batting and pitching data for BOS
# Combined batting and pitching data for CHW
# Combined batting and pitching data for CLE
# Combined batting and pitching data for DET
# Combined batting and pitching data for KCR
# Combined batting and pitching data for MIN
# Combined batting and pitching data for NYY
# Combined batting and pitching data for OAK
# Combined batting and pitching data for SEA
# Combined batting and pitching data for TBR
# Combined batting and pitching data for TEX
# Combined batting and pitching data for TOR
# Combined batting and pitching data for ARI
# Combined batting and pitching data for ATL
# Combined batting and pitching data for CHC
# Combined batting and pitching data for CIN
# Combined batting and pitching data for COL
# Combined batting and pitching data for LAD
# Combined batting and pitching data for SDP
# Combined batting and pitching data for MIA
# Combined batting and pitching data for NYM
# Combined batting and pitching data for PHI
# Combined batting and pitching data for PIT
# Combined batting and pitching data for SFG
# Combined batting and pitching data for STL
# Combined batting and pitching data for TBD
# Combined batting and pitching data for WSN

# %%
def add_cols_to_events():
    event_df = pd.read_csv('data/raw/retrosheet_events.csv')
    event_df['run_diff'] = event_df['home_score'].copy() - event_df['visiting_score'].copy()
    event_df['home_victory'] = (event_df['run_diff'] > 0).astype(int)
    event_df['run_total'] = event_df['home_score'].copy() + event_df['visiting_score'].copy()
    event_df['date_dblhead'] = (event_df['date'].copy().astype(str) + event_df['game_num'].copy().astype(str)).astype(int)
    event_df.to_csv('data/custom/retrosheet_events.csv')
    print('Event data updated with custom columns')

add_cols_to_events()
# Out:
# /tmp/ipykernel_211096/4020097100.py:2: DtypeWarning: Columns (14,15,16,86,88) have mixed types. Specify dtype option on import or set low_memory=False.
#   event_df = pd.read_csv('data/raw/retrosheet_events.csv')
